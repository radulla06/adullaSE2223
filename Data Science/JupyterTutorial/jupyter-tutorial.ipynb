# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Create Basic Graph

# %%
x = [1, 2, 3]   # Time
y = [2, 4, 6]   # Distance

plt.plot(x, y)
plt.title("Distance vs Time")
plt.xlabel("Time")
plt.ylabel("Distance")
plt.show()
